# %% [markdown]
# # Exceptions and Command Line Arguments

# %% [raw]
# 1. Write python program with Exception handling to input marks for five subjects Physics, Chemistry, Biology, Mathematics, and Computer. Calculate the percentage and grade according to the following:
#
# i)Percentage >= 90% : Grade A
#
# ii)Percentage >= 80% : Grade B
#
# iii)Percentage >= 70% : Grade C
#
# iv) Percentage >= 60% : Grade D
#
# v) Percentage >= 40% : Grade E
#
# vi) Percentage<40%: Grade F

# %%
try:
    # Input marks for five subjects
    physics = float(input("Enter Physics marks: "))
    chemistry = float(input("Enter Chemistry marks: "))
    biology = float(input("Enter Biology marks: "))
    mathematics = float(input("Enter Mathematics marks: "))
    computer = float(input("Enter Computer marks: "))

    # Check if the entered marks are within a valid range (0-100)
    if any(m < 0 or m > 100 for m in [physics, chemistry, biology, mathematics, computer]):
        raise ValueError("Invalid marks. Marks should be between 0 and 100.")

    # Calculate the percentage
    total_marks = physics + chemistry + biology + mathematics + computer
    percentage = (total_marks / 500) * 100

    # Determine the grade based on the percentage
    if percentage >= 90:
        grade = "A"
    elif percentage >= 80:
        grade = "B"
    elif percentage >= 70:
        grade = "C"
    elif percentage >= 60:
        grade = "D"
    elif percentage >= 40:
        grade = "E"
    else:
        grade = "F"

    # Display the percentage and grade
    print(f"Percentage: {percentage:.2f}%")
    print(f"Grade: {grade}")

except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Enter Physics marks: 94
# Enter Chemistry marks: 91
# Enter Biology marks: 96
# Enter Mathematics marks: 99
# Enter Computer marks: 95
# Percentage: 95.00%
# Grade: A

# %% [raw]
# 2. Write a python program with Exception handling to input electricity unit charges and calculate the total electricity bill according to the given condition:
#
# i)For the first 50 units Rs. 0.50/unit
#
# ii)For the next 100 units Rs. 0.75/unit
#
# iii)For the next 100 units Rs. 1.20/unit
#
# iv) For units above 250 Rs. 1.50/unit
#
# v)An additional surcharge of 20% is added to the bill.

# %%
try:
    # Input electricity unit charges
    units = float(input("Enter electricity units consumed: "))

    # Check if the entered units are non-negative
    if units < 0:
        raise ValueError("Units consumed cannot be negative.")

    # Calculate the total electricity bill based on the given conditions
    if units <= 50:
        bill = units * 0.50
    elif units <= 150:
        bill = 50 * 0.50 + (units - 50) * 0.75
    elif units <= 250:
        bill = 50 * 0.50 + 100 * 0.75 + (units - 150) * 1.20
    else:
        bill = 50 * 0.50 + 100 * 0.75 + 100 * 1.20 + (units - 250) * 1.50

    # Calculate the surcharge (20% of the bill)
    surcharge = 0.20 * bill

    # Calculate the total bill including surcharge
    total_bill = bill + surcharge

    # Display the total electricity bill
    print(f"Total Electricity Bill: Rs. {total_bill:.2f}")

except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Enter electricity units consumed: 150
# Total Electricity Bill: Rs. 120.00

# %% [raw]
# 3. Write a python program with Exception handling to input the week number and print the weekday.

# %%
try:
    # Input week number
    week_number = int(input("Enter a week number (1-7): "))

    # Check if the entered week number is within the valid range (1-7)
    if week_number < 1 or week_number > 7:
        raise ValueError("Week number should be between 1 and 7.")

    # Define a list of weekdays
    weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

    # Print the corresponding weekday
    print(f"Weekday for week {week_number} is {weekdays[week_number - 1]}.")

except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Enter a week number (1-7): 6
# Weekday for week 6 is Saturday.

# %% [raw]
# 4. Write a Python program to implement word count using command line arguments.
#
# i) Create a text document "apple.txt" whch contains text for wordcount.
#
# ii)Create a wordcount program which calls the "apple.txt" document by opening the file.
#
# iii)If the word is present again in the "aaple.txt", the wordcount is incremented by 1 until all the words are counted in the document.
#
# iv) Close the file.
#
# v) Create a command.py program which imports the wordcount.py program.
#
# vi) Count the number of words using command line arguments.
#
# vii) Print each word and its count.

# %%
# This is the word_count program I executed in command prompt
import sys

def word_count(file_name):
    try:
        # Open the file in read mode
        with open(file_name, 'r') as file:
            text = file.read()

            # Split the text into words using whitespace as a delimiter
            words = text.split()

            # Initialize a dictionary to store word counts
            word_counts = {}

            # Count the occurrence of each word
            for word in words:
                word = word.lower()  # Convert to lowercase to count words case-insensitively
                if word in word_counts:
                    word_counts[word] += 1
                else:
                    word_counts[word] = 1

            # Print the word counts
            for word, count in word_counts.items():
                print(f"{word}: {count}")

    except FileNotFoundError:
        print(f"Error: {file_name} not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Usage: python word_count.py <file_name>")
    else:
        file_name = sys.argv[1]
        word_count(file_name)
# Out:
# Usage: python word_count.py <file_name>

# %%
# Tis is Command.py code and this was executed in command prompt 
import sys
from word_count import word_count

if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Usage: python command.py <file_name>")
    else:
        file_name = sys.argv[1]
        word_counts = word_count(file_name)

        for word, count in word_counts.items():
            print(f"{word}: {count}")

# %%
5. Write a Python program for finding the most frequent words in a text read from a file.

i) Initially open the text file in read mode.

ii) Make all the letters in the document into lowercase letters and split the words in each linc.

iii) Get the words in an order.

iv) Sort the words for finding the most frequent words in the file.
v) Print the most frequent words in the file.

# %%
from collections import Counter

# Step 1: Open the text file in read mode
with open('source.txt', 'r') as file:
    text = file.read()

# Step 2: Make all letters lowercase and split the words
words = text.lower().split()

# Step 3: Get the words in order
# No additional steps needed as words are already in order

# Step 4: Count word frequency using Counter
word_count = Counter(words)

# Step 5: Find the most frequent words
most_common_words = word_count.most_common()

# Print the most frequent words
print("The most frequent words in the file are:")
for word, count in most_common_words:
    print(f"{word}: {count}")
# Out:
# The most frequent words in the file are:
# to: 27
# is: 22
# a: 21
# aiml: 19
# and: 18
# create: 17
# the: 17
# of: 17
# that: 17
# used: 13
# language: 11
# by: 10
# for: 9
# artificial: 9
# intelligence: 9
# natural: 9
# rules: 9
# can: 8
# be: 8
# with: 8
# or: 7
# it: 6
# software: 6
# in: 6
# are: 6
# respond: 5
# what: 4
# aiml?: 4
# markup: 4
# was: 4
# aiml,: 4
# chatbots: 4
# other: 4
# how: 4
# applications.: 4
# if: 4
# also: 4
# virtual: 4
# you: 4
# your: 4
# an: 3
# agents.: 3
# developed: 3
# language,: 3
# dr.: 3
# richard: 3
# wallace: 3
# chatbot: 3
# should: 3
# inputs.: 3
# example,: 3
# application: 3
# input: 3
# want: 3
# some: 3
# processing: 3
# human: 3
# difficult: 3
# all: 3
# language.: 2
# xml-based: 2
# form: 2
# xml: 2
# 1995: 2
# has: 2
# been: 2
# number: 2
# companies: 2
# organizations: 2
# software.: 2
# set: 2
# define: 2
# computer: 2
# rule: 2
# user: 2
# ai: 2
# will: 2
# very: 2
# applications: 2
# research: 2
# development: 2
# systems.: 2
# programs: 2
# such: 2
# as: 2
# challenges: 2
# name?": 2
# need: 2
# conversation: 2
# acronym: 1
# programmers: 1
# foundation: 1
# early: 1
# 1990s.: 1
# history: 1
# created: 1
# based: 1
# on: 1
# various: 1
# these: 1
# customized: 1
# unique: 1
# each: 1
# individual: 1
# organization.: 1
# does: 1
# work?: 1
# computers: 1
# communicate: 1
# humans.: 1
# works: 1
# providing: 1
# templates: 1
# certain: 1
# might: 1
# state: 1
# says: 1
# "hello,": 1
# "hello,: 1
# you?": 1
# when: 1
# interacts: 1
# uses: 1
# look: 1
# match: 1
# user's: 1
# input.: 1
# no: 1
# match,: 1
# try: 1
# find: 1
# similar: 1
# accordingly.: 1
# flexible: 1
# simple: 1
# complex: 1
# easy: 1
# learn,: 1
# making: 1
# good: 1
# choice: 1
# those: 1
# who: 1
# their: 1
# own: 1
# now: 1
# maintained: 1
# consortium.: 1
# chatbots,: 1
# assistants,: 1
# forms: 1
# versatile: 1
# wide: 1
# variety: 1
# more: 1
# popular: 1
# include:: 1
# chatbots:: 1
# commonly: 1
# chatbots.: 1
# mimic: 1
# conversation.: 1
# allows: 1
# understand: 1
# way.: 1
# assistants:: 1
# assistants.: 1
# assistants: 1
# help: 1
# users: 1
# tasks: 1
# scheduling: 1
# appointments,: 1
# sending: 1
# email,: 1
# searching: 1
# internet.: 1
# processing:: 1
# branch: 1
# deals: 1
# understanding: 1
# generating: 1
# one: 1
# cover: 1
# possible: 1
# responds: 1
# "what: 1
# variations: 1
# question,: 1
# "what's: 1
# "tell: 1
# me: 1
# name.": 1
# another: 1
# challenge: 1
# conversational.: 1
# bot: 1
# able: 1
# have: 1
# about: 1
# weather,: 1
# different: 1
# ways: 1
# could: 1
# go.: 1
# this: 1
# do: 1
# without: 1
# sounding: 1
# like: 1
# robot.: 1

# %% [raw]
# 6. File Processing with Command-Line Arguments- Scenario: You are developing a command-line utility that processes text files. Users can specify input and output file paths as command-line arguments. Your program should handle exceptions gracefully.
#
# i). Design a Python program that takes two command-line arguments: the input file path and the output file path. Ensure that the program checks if both arguments are provided and that the input file exists.
#
# ii).Implement error handling to deal with scenarios such as missing input files, invalid file paths, or permission issues when writing to the output file.
#
# iii).If an error occurs during file processing, display a user-friendly error message, and exit the program with a non-zero exit code.
#
# iv). Write test cases that cover various scenarios, including providing valid and invalid file paths as command-line arguments.

# %%
import sys
import os

def process_files(input_file_path, output_file_path):
    try:
        # Check if both input and output file paths are provided
        if not input_file_path or not output_file_path:
            raise ValueError("Both input and output file paths are required.")
        
        # Check if the input file exists
        if not os.path.exists(input_file_path):
            raise FileNotFoundError(f"Input file '{input_file_path}' does not exist.")

        # Read data from the input file and process it
        with open(input_file_path, 'r') as input_file, open(output_file_path, 'w') as output_file:
            for line in input_file:
                # Your processing logic can go here
                # For this example, we'll just copy the lines from input to output
                output_file.write(line)

        print("File processing completed successfully.")
    except ValueError as ve:
        print(f"Error: {ve}")
        sys.exit(1)
    except FileNotFoundError as fnfe:
        print(f"Error: {fnfe}")
        sys.exit(1)
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        sys.exit(1)

if __name__ == "__main__":
    if len(sys.argv) != 3:
        print("Usage: python program.py input_file output_file")
        sys.exit(1)

    input_file_path = sys.argv[1]
    output_file_path = sys.argv[2]

    process_files(input_file_path, output_file_path)
